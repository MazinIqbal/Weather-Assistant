# %%
# Weather Assistant by Mazin Iqbal.
import requests

# Introduction
print("Welcome! This is a quick program that generates a weather report for any city in the world.")

# Input
location = input("Please enter the city: ")

# Report
url = 'https://wttr.in/{}'.format(location)
report = requests.get(url)

# Output
print(report.text)
# Out:
# Welcome! This is a quick program that generates a weather report for any city in the world.
# Please enter the city: Maryland
# Weather report: Maryland
#
#       \   /     Clear
#        .-.      +37(30) °F
#     ― (   ) ―   ↗ 5 mph
#        `-’      9 mi
#       /   \     0.0 in
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Sun 14 Nov ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │    \  /       Partly cloudy  │    \  /       Partly cloudy  │    \  /       Partly cloudy  │
# │      .-.      +33(28) °F     │  _ /"".-.     +42(37) °F     │  _ /"".-.     +44(39) °F     │  _ /"".-.     +44(37) °F     │
# ...
